# %% [markdown]
# <a href="https://colab.research.google.com/github/nonoumasy/ACLED/blob/master/ACLED.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/1900-01-01-2020-04-11.csv', error_bad_lines=False, engine='python')

# %%
df.head()
# Out:
#    data_id  iso event_id_cnty  ...  fatalities   timestamp  iso3
# 0  7031808  804      UKR35530  ...           0  1586276654   UKR
# 1  7031809  804      UKR35538  ...           0  1586276654   UKR
# 2  7030274  484      MEX16763  ...           1  1586202168   MEX
# 3  7031810  804      UKR35541  ...           0  1586276654   UKR
# 4  7030791   76      BRA13435  ...           1  1586210135   BRA
#
# [5 rows x 31 columns]

# %%
df.year.unique()
# Out:
# array([2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010,
#        2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000, 1999,
#        1998, 1997])

# %%
df[df.year == 1997]
# Out:
#         data_id  iso event_id_cnty  ...  fatalities   timestamp  iso3
# 752503  5817111  694       SIE1013  ...           0  1567462216   SLE
# 752504  5817112  694       SIE1014  ...           0  1567462216   SLE
# 752505  5817115  694       SIE1018  ...           0  1567462216   SLE
# 752506  5817116  694       SIE1019  ...           0  1567462216   SLE
# 752507  5817120  694       SIE1016  ...           0  1567462216   SLE
# ...         ...  ...           ...  ...         ...         ...   ...
# 755770  5816572  694          SIE8  ...           0  1567462216   SLE
# 755771  5816573  694          SIE9  ...           0  1567462216   SLE
# 755772  6876157  729          SUD2  ...           0  1582579226   SDN
# 755773  6876158  694          SIE2  ...           0  1582579226   SLE
# 755774  6876159   24          ANG1  ...          30  1582579226   AGO
#
# [3272 rows x 31 columns]
